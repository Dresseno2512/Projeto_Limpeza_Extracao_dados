# %%
import pandas as pd # bibliote Pandas é usada para manipulação de dados
import matplotlib.pyplot as plt # biblioteca para visualização dos dados
import numpy as np
# CSV file
data = pd.read_excel("C:\\Users\\eduar\\3D Objects\\OneDrive\\Área de Trabalho\\opçõeswege.xlsx", header=(1))
print("Número de linhas e colunas:",data.shape)
data.head(25)
# Out:
# Número de linhas e colunas: (348, 8)
#        Série Preço de Exercício Coberto  Trava Descoberto   Total Titular  \
# 0   WEGEC259              25.71     600   5500       5500   11600       2
# 1   WEGEC269              26.71       0      0       1300    1300       1
# 2   WEGEC279              27.71    2000   1500          0    3500       2
# 3   WEGEC289              28.71    2500      0        400    2900       1
# 4   WEGEC292              28.96       0      0      26600   26600       2
# 5   WEGEC294              29.21    6400      0        700    7100       2
# 6   WEGEC299              29.71     500      0      20200   20700       2
# 7   WEGEC304              30.21     200      0       4100    4300       2
# 8   WEGEC307              30.46     500      0     110000  110500       3
# 9   WEGEC309              30.71       0      0      14700   14700       2
# 10   WEGEC31              30.96     500      0       9700   10200       2
# ...

# %%
# Renomear as colunas
data = data.rename(columns={
    "Unnamed: 0": "Opção",
    "Unnamed: 1": "Strike",
    "Coberto": "Coberto",
    "Trava": "Trava",
    "Descoberto": "Descoberto",
    "Total": "Total",
    "Titular": "Titular",
    "Lançador": "Lançador"
})

print("Número de linhas e colunas:", data.shape)
print(data.head(100))
# Out:
# Número de linhas e colunas: (348, 8)
#        Série Preço de Exercício Coberto   Trava Descoberto   Total Titular  \
# 0   WEGEC259              25.71     600    5500       5500   11600       2
# 1   WEGEC269              26.71       0       0       1300    1300       1
# 2   WEGEC279              27.71    2000    1500          0    3500       2
# 3   WEGEC289              28.71    2500       0        400    2900       1
# 4   WEGEC292              28.96       0       0      26600   26600       2
# ..       ...                ...     ...     ...        ...     ...     ...
# 95  WEGED401              39.93    1900    1400       2300    5600       4
# 96  WEGED404              40.18    4700  222900      20100  247700       5
# 97  WEGED406              40.43       0     500       3700    4200       3
# 98  WEGED409              40.68   23000   94000       3000  120000       6
# 99  WEGED411              40.93       0       0       1200    1200       2
#
#    Lançador
# 0         4
# ...

# %%
print(data.dtypes)
# Out:
# Série                 object
# Preço de Exercício    object
# Coberto               object
# Trava                 object
# Descoberto            object
# Total                 object
# Titular               object
# Lançador              object
# dtype: object

# %% [markdown]
# 		Coberto	Trava	Descoberto	Total	Titular	Lançador
# PETRC1	33,01	12.600	311.600	384.500	708.700	55	19
# PETRC100	20,51	8.500	21.200	106.800	136.500	5	16
# PETRC104	18,26	31.700	14.900	237.200	283.800	5	46
# PETRC105	10,51	0	18.200	231.000	249.200	4	7
# PETRC109	18,76	6.300	13.600	38.700	58.600	4	21
# PETRC110	19,51	600	0	8.600	9.200	2	6
# PETRC113	20,01	4.100	34.000	230.200	268.300	7	25
# PETRC117	11,76	400	0	7.200	7.600	3	5
# PETRC118	20,26	18.400	0	111.800	130.200	3	17
# PETRC119	8,06	1.500	5.300	3.500	10.300	3	8
# PETRC120	12,01	0	0	220.000	220.000	3	1
# PETRC121	8,36	500	0	0	500	1	1
# PETRC122	12,26	50.300	4.800	61.600	116.700	5	23
# PETRC123	8,56	1.200	6.400	45.600	53.200	3	10
# PETRC127	12,76	1.300	0	800	2.100	2	2
# PETRC129	19,01	8.700	32.200	26.500	67.400	4	15
# PETRC13	13,26	23.600	1.700	29.300	54.600	4	21

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2544\2832199218.py in <module>
# ----> 1 vetor_serie = dados['Série'].values
#       2 vetor_preco = dados['Preço de Exercício'].values
#       3 vetor_coberto = dados['Coberto'].values
#       4 vetor_trava = dados['Trava'].values
#       5 vetor_descoberto = dados['Descoberto'].values
#
# NameError: name 'dados' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

# CSV file
#data = pd.read_excel("C:\\Users\\eduar\\3D Objects\\OneDrive\\Área de Trabalho\\opçõeswege.xlsx", header=(1))


print("Número de linhas e colunas:")
linhas, colunas = data.shape
print("Número de linhas:", linhas)
print("Número de colunas:", colunas)
print(data.head(25))
print(data.dtypes)

vetor_serie = data['Série'].values
vetor_preco = data['Preço de Exercício'].values
vetor_coberto = data['Coberto'].values
vetor_trava = data['Trava'].values
vetor_descoberto = data['Descoberto'].values

plt.scatter(data['Preço de Exercício'], data['Descoberto'])
plt.xlabel('Preço de Exercício')
plt.ylabel('Descoberto')
plt.show()
# Out:
# Número de linhas e colunas:
# Número de linhas: 348
# Número de colunas: 8
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0    WEGEC259      25.71        600       5500       5500      11600
# 1    WEGEC269      26.71          0          0       1300       1300
# 2    WEGEC279      27.71       2000       1500          0       3500
# 3    WEGEC289      28.71       2500          0        400       2900
# 4    WEGEC292      28.96          0          0      26600      26600
# 5    WEGEC294      29.21       6400          0        700       7100
# 6    WEGEC299      29.71        500          0      20200      20700
# 7    WEGEC304      30.21        200          0       4100       4300
# 8    WEGEC307      30.46        500          0     110000     110500
# 9    WEGEC309      30.71          0          0      14700      14700
# 10    WEGEC31      30.96        500          0       9700      10200
# ...

# %%
import pandas as pd # bibliote Pandas é usada para manipulação de dados
import matplotlib.pyplot as plt # biblioteca para visualização dos dados
import numpy as np
# CSV file
#data = pd.read_excel("C:\\Users\\eduar\\3D Objects\\OneDrive\\Área de Trabalho\\opçõeswege.xlsx", header=(1))
data = pd.read_excel("C:\\Users\\eduar\\3D Objects\\OneDrive\\Área de Trabalho\\opçõeswege.xlsx", header=0, skiprows=[1])
print("Número de linhas e colunas:",data.shape)
data.head(25)


print(data.dtypes)



#vetor_serie = data['Série'].values
vetor_preco = data['Preço de Exercício'].values
vetor_coberto = data['Coberto'].values
vetor_trava = data['Trava'].values
vetor_descoberto = data['Descoberto'].values

plt.scatter(data['Preço de Exercício'], data['Descoberto'])
plt.xlabel('Preço de Exercício')
plt.ylabel('Descoberto')
plt.show()


#Preço = data['Preço de Exercício'].values
#Descoberto = data['Descoberto'].values

# plotagem do gráfico
#plt.scatter(Preco, Descoberto)
#plt.xlabel('Preço de Exercício')
#plt.ylabel('Descoberto')
#plt.show()
# Out:
# Número de linhas e colunas: (348, 8)
# Unnamed: 0    object
# Unnamed: 1    object
# Unnamed: 2    object
# Unnamed: 3    object
# Unnamed: 4    object
# Unnamed: 5    object
# Unnamed: 6    object
# Unnamed: 7    object
# dtype: object
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda2\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\Anaconda2\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda2\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# leitura dos dados
data = pd.read_excel("C:\\Users\\eduar\\3D Objects\\OneDrive\\Área de Trabalho\\opçõeswege.xlsx", header=0, skiprows=[1])

# criação dos vetores
preco_exercicio = data['Preço de Exercício'].dropna().values
descoberto = data['Descoberto'].dropna().values

# plotagem do gráfico
plt.plot(preco_exercicio, descoberto, 'bo')
plt.xlabel('Preço de Exercício')
plt.ylabel('Descoberto')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda2\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\Anaconda2\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda2\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Preço de Exercício'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
